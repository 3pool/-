# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from  pyecharts import WordCloud

# %%
df = pd.read_excel('./规模以上用能企业主要能源品种消费量情况.xlsx')

# %%
df
# Out:
#                 name      num
# 0        原煤13891.6万吨  13891.6
# 1   洗精煤（用于炼焦）262.6万吨    262.6
# 2         其它洗煤94.5万吨     94.5
# 3          煤制品75.6万吨     75.6
# 4          焦炭272.1万吨    272.1
# 5       其它焦化产品18.2万吨     18.2
# 6         原油5090.5万吨   5090.5
# 7           汽油13.4万吨     13.4
# 8            煤油0.8万吨      0.8
# 9           柴油65.1万吨     65.1
# 10        燃料油133.8万吨    133.8
# 11      液化石油气462.3万吨    462.3
# 12      天然气119.7亿立方米    119.7
# 13      电力2454.9亿千瓦时   2454.9
# 14     热力50900.5百亿千焦  50900.5
# 15    余热余压8705.4百亿千焦   8705.4

# %%
cy = WordCloud('规模以上用能企业主要能源品种消费量情况')
cy.add('', df.name , df.num ,
#       shape = 'circle',
       word_size_range= [10,100],
#        rotate_step = 10
      )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="a576129587374f1e863a4513dfc02985" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_a576129587374f1e863a4513dfc02985 = echarts.init(document.getElementById('a576129587374f1e863a4513dfc02985'), 'light', {renderer: 'canvas'});
#
# var option_a576129587374f1e863a4513dfc02985 = {
#     "title": [
#         {
#             "text": "\u89c4\u6a21\u4ee5\u4e0a\u7528\u80fd\u4f01\u4e1a\u4e3b\u8981\u80fd\u6e90\u54c1\u79cd\u6d88\u8d39\u91cf\u60c5\u51b5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
# ...
